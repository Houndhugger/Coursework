# %%
import torch
import numpy as np
from sklearn.preprocessing import StandardScaler




import xlrd
import pandas as pd
book = xlrd.open_workbook('prepareddata.xlsx')
sheet = book.sheet_by_name('Sheet1')
data = [[sheet.cell_value(r, c)
         for c in range(0,8)] for r in range(0,7272)]

scaler = StandardScaler()


standardised_data = scaler.fit_transform(data)
print(scaler.mean_, scaler.var_)

np.random.shuffle(standardised_data)
array1 = standardised_data[:, 0:5]
array2 = standardised_data[:, 5:8]
x = torch.tensor(array1)
y = torch.tensor(array2)

print(x)
print(y)
# Out:
# [1.17685992e+00 2.50797002e+03 2.03207622e+00 3.30000000e+02
#  3.00000000e-01 1.50880269e-02 4.55572536e+01 2.53751017e-02] [5.29632128e-01 1.01472949e+07 1.74973000e+00 2.70000000e+04
#  4.00000000e-02 3.34068516e-05 4.87490021e+03 2.03739307e-04]
# tensor([[-0.8029, -0.6256, -0.8918, -1.0954, -1.0000],
#         [ 1.7678, -0.3763,  2.0607,  1.6432, -1.0000],
#         [ 0.4465, -0.1786,  0.2957, -1.0954, -1.0000],
#         ...,
#         [-1.0588, -0.5987, -1.0375, -1.0954, -1.0000],
#         [-1.5117, -0.5474, -1.5362, -0.1826,  1.0000],
#         [-0.5887, -0.6451, -0.6296, -1.0954, -1.0000]], dtype=torch.float64)
# tensor([[-0.3799, -0.7152,  0.2980],
#         [-0.3943, -0.4149, -0.8970],
#         [-2.1841, -0.3542, -1.8239],
#         ...,
#         [-0.0026, -0.7512, -0.6991],
#         [-0.6136, -0.9838,  0.1489],
#         [-0.3800, -0.3772,  0.1983]], dtype=torch.float64)

# %%
book = xlrd.open_workbook('prepareddata.xlsx')
sheet = book.sheet_by_name('Sheet1')
data4 = [[sheet.cell_value(r, c)
         for c in range(0,5)] for r in range(0,7272)]
data5 = [[sheet.cell_value(r, c)
         for c in range(5,8)] for r in range(0,7272)]
scaler = StandardScaler()
scaler2 = StandardScaler()



book = xlrd.open_workbook('Experimental Data edited.xlsx')
sheet = book.sheet_by_name('Sheet2')
data = [[sheet.cell_value(r, c)
         for c in range(1,6)] for r in range(98,110)]
data2 = [[sheet.cell_value(r, c)
         for c in range(7,10)] for r in range(98,110)]

scaler.fit(data4)
scaler2.fit(data5)
standardised_data = scaler.transform(data)
standardiseddx_dt = scaler2.transform(data2)

# %%
import torch.nn as nn
class Net(nn.Module):
    def __init__(self, D_in, H1, H2, D_out):
 
        super(Net, self).__init__()
        self.linear1 = nn.Linear(D_in, H1) 
        self.linear2 = nn.Linear(H1, H2)
        self.linear3 = nn.Linear(H2, D_out)
  
    def forward(self, x):
    
        x = torch.sigmoid(self.linear1(x))
        x = torch.sigmoid(self.linear2(x))
        x = self.linear3(x)
        return x

# %%
# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.

loss_fn = torch.nn.MSELoss(reduction='mean')

# %%
from tqdm import tqdm
learning_rate = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

epochs = 400
for l in range (5,25,5):
    for q in range (3,15,3):
        N, D_in, H1, H2, D_out = 50, 5, l, q, 3
        model = Net(D_in, H1, H2, D_out)
        model.train()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        for epoch in range (epochs):
    
            for i in tqdm(range(0, len(x), N)):
                batch_x = x[i:i+N]
                batch_y = y[i:i+N]
    # Forward pass
                optimizer.zero_grad()
                dx_dt_pred = model(batch_x.float())
   
    # Compute and print loss.
                loss = loss_fn(dx_dt_pred, batch_y.float())

    # Before the backward pass, use the optimizer object to zero all of the
    # gradients for the variables it will update (which are the learnable
    # weights of the model). This is because by default, gradients are
    # accumulated in buffers( i.e, not overwritten) whenever .backward()
    # is called. Checkout docs of torch.autograd.backward for more details.
       
                loss.backward()
                optimizer.step()
           

        r = torch.tensor(standardised_data)
        d = torch.tensor(standardiseddx_dt)
        dx_dt_pred_test = model(r.float())
        loss = loss_fn(dx_dt_pred_test,d.float())
        print(d)
        print(dx_dt_pred_test)
        print(H1,H2)
        print(loss.item())

print(batch_y)    
print(dx_dt_pred)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 909.17it/s]
# 0 0.7946425676345825
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 969.12it/s]
# 1 0.7719258666038513
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 982.49it/s]
# 2 0.7158838510513306
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 965.41it/s]
# 3 0.6313756704330444
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 969.47it/s]
# 4 0.5629184246063232
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 963.10it/s]
# 5 0.5329097509384155
# 100%|███████████████████████████████████████████████████████████████████████████████| 146/146 [00:00<00:00, 962.93it/s]
# ...

# %%
torch.save(model.state_dict(), ("C:/Users/Gabriel/Documents/Python/ANN2.pt"))

# %%
print(data2)
# Out:
# [[0.01783333333333333, 24.988333333333344, 0.050833333333333335], [0.023416666666666665, -32.44333333333335, 0.04166666666666668], [0.02313333333333334, -9.365833333333322, 0.041666666666666664], [0.020691666666666674, 32.817499999999995, 0.034999999999999976], [0.019733333333333325, -26.63583333333334, 0.03500000000000003], [0.015975, 132.69500000000005, 0.02749999999999997], [0.01776666666666667, 242.3891666666666, 0.027500000000000007], [0.012699999999999989, 146.2941666666667, 0.029166666666666674], [0.013891666666666672, 193.01666666666657, 0.01416666666666666], [0.01153333333333332, 129.1691666666667, 0.025000000000000022], [0.009850000000000025, 118.19666666666672, 0.01833333333333335], [0.010924999999999999, 140.48833333333323, 0.00916666666666662]]
